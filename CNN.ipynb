# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import seaborn as sns
import xgboost as xgb
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

from IPython.display import Image, display
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

from sklearn.preprocessing import OrdinalEncoder

# %%
train_df = pd.read_csv('/content/train.csv')
transactions_df = pd.read_csv('/content/transactions.csv')
stores_df = pd.read_csv('/content/stores.csv')

train_df = pd.merge(train_df,stores_df,how='left',on='store_nbr')
train_df.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion   city  \
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0  Quito
# 1   1  2013-01-01          1   BABY CARE    0.0            0  Quito
# 2   2  2013-01-01          1      BEAUTY    0.0            0  Quito
# 3   3  2013-01-01          1   BEVERAGES    0.0            0  Quito
# 4   4  2013-01-01          1       BOOKS    0.0            0  Quito
#
#        state type  cluster
# 0  Pichincha    D       13
# 1  Pichincha    D       13
# 2  Pichincha    D       13
# 3  Pichincha    D       13
# 4  Pichincha    D       13

# %%
oil_df = pd.read_csv('/content/oil.csv')
oil_df['date'] = pd.to_datetime(oil_df['date'])

oil_df
# Out:
#            date  dcoilwtico
# 0    2013-01-01         NaN
# 1    2013-01-02       93.14
# 2    2013-01-03       92.97
# 3    2013-01-04       93.12
# 4    2013-01-07       93.20
# ...         ...         ...
# 1213 2017-08-25       47.65
# 1214 2017-08-28       46.40
# 1215 2017-08-29       46.46
# 1216 2017-08-30       45.96
# 1217 2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
print(len(train_df.date.unique()) , len(oil_df.date.unique()))

dates_df = pd.DataFrame(train_df.date.unique(), columns=['date'])
dates_df['date'] = pd.to_datetime(dates_df['date'], errors='coerce')
dates_df = dates_df.dropna()  # drop rows with missing dates

oil_df = pd.merge(dates_df, oil_df, how="left", on="date")
oil_df = oil_df.set_index('date')
oil_df.shape
# Out:
# 1684 1218
# (1684, 1)

# %%
print(oil_df.query('dcoilwtico != dcoilwtico'))
print(oil_df.isnull().sum())
print(oil_df.describe())
# Out:
#             dcoilwtico
# date
# 2013-01-01         NaN
# 2013-01-05         NaN
# 2013-01-06         NaN
# 2013-01-12         NaN
# 2013-01-13         NaN
# ...                ...
# 2017-07-30         NaN
# 2017-08-05         NaN
# 2017-08-06         NaN
# 2017-08-12         NaN
# 2017-08-13         NaN
#
# [521 rows x 1 columns]
# dcoilwtico    521
# dtype: int64
#         dcoilwtico
# count  1163.000000
# mean     67.925589
# std      25.677366
# min      26.190000
# 25%      46.390000
# 50%      53.330000
# 75%      95.790000
# max     110.620000

# %%
import plotly.express as px

fig = px.line(oil_df, x = oil_df.index, y ='dcoilwtico', title='Plot slider for oil prices')
fig.update_xaxes(
    rangeslider_visible = True,
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fad0e467-604f-46ce-8e5f-580d9805f179" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
:00:00","2013-04-21T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-27T00:00:00","2013-04-28T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-04T00:00:00","2013-05-05T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-11T00:00:00","2013-05-12T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-18T00:00:00","2013-05-19T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-25T00:00:00","2013-05-26T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00: ...

# %%
oil_na = oil_df.copy()
oil_na.dropna()
# Out:
#             dcoilwtico
# date
# 2013-01-02       93.14
# 2013-01-03       92.97
# 2013-01-04       93.12
# 2013-01-07       93.20
# 2013-01-08       93.21
# ...                ...
# 2017-08-09       49.59
# 2017-08-10       48.54
# 2017-08-11       48.81
# 2017-08-14       47.59
# 2017-08-15       47.57
#
# [1163 rows x 1 columns]

# %%
pd.plotting.autocorrelation_plot(oil_na['2015':'2016']['dcoilwtico'])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
pd.plotting.autocorrelation_plot(oil_df['2015':'2016']['dcoilwtico'].resample('1m').mean())
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
pd.plotting.lag_plot(oil_df['dcoilwtico'], lag= 1)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
pd.plotting.lag_plot(oil_df['dcoilwtico'], lag= 3)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 3)'>

# %%
pd.plotting.lag_plot(oil_df['dcoilwtico'], lag= 30)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 30)'>

# %%
oil_df['dcoilwtico'][0] = oil_df['dcoilwtico'][1].copy()
oil_df = oil_df.interpolate(method='linear')

# %%
fig = px.line(oil_df, x = oil_df.index, y ='dcoilwtico', title='Plot slider for oil prices')
fig.update_xaxes(
    rangeslider_visible = True,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d2fbad40-c730-44e8-9e70-930c0d0082aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2fbad40-c730-44e8-9e70-930c0d0082aa")) {                    Plotly.newPlot(                        "d2fbad40-c730-44e8-9e70-930c0d0082aa",                        [{"hovertemplate":"date=%{x}<br>dcoilwtico=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["
00:00:00","2013-05-05T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-11T00:00:00","2013-05-12T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-18T00:00:00","2013-05-19T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-25T00:00:00","2013-05-26T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00: ...

# %%
train_df['date'] = pd.to_datetime(train_df['date'], errors="coerce")
train_df=train_df.dropna()
train_df = train_df.set_index('date')

# %%
train_df.groupby(['city']).sales.mean().plot(kind='bar');

# %%
train_df.groupby('store_nbr')[['onpromotion','sales']].sum().plot.scatter('onpromotion','sales')
plt.title('Promotion and Sales Relationship')
# Out:
# Text(0.5, 1.0, 'Promotion and Sales Relationship')

# %%
train_df = pd.merge(train_df,oil_df,how='left',on='date')

# %%
print(train_df.query('dcoilwtico !=dcoilwtico'))
# Out:
# Empty DataFrame
# Columns: [id, store_nbr, family, sales, onpromotion, city, state, type, cluster, dcoilwtico]
# Index: []

# %%
grouped = train_df.groupby(['date']).agg({'dcoilwtico': 'mean', 'sales': 'mean'})
fig = px.line(grouped, x=grouped.index , y=['sales', 'dcoilwtico'])
fig.update_layout(title='Sale and Date Plot')
fig.show()
del grouped
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="786055fb-3b33-45f6-abda-d1ce9a60194b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("786055fb-3b33-45f6-abda-d1ce9a60194b")) {                    Plotly.newPlot(                        "786055fb-3b33-45f6-abda-d1ce9a60194b",                        [{"hovertemplate":"variable=sales<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"sales","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"sales","showlegend":true,"x":["2013-01-01T00:00:00","2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-05T00:00:00","2013-01-06T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-12T00:00:00","2013-01-13T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-19T00:00:00","2013-01-20T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-26T00:00:00","2013-01-27T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-02T00:00:00","2013-02-03T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-09T00:00:00","2013-02-10T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T
# 2013-01-01   3          1   BEVERAGES    0.0            0  Quito  Pichincha
# 2013-01-01   4          1       BOOKS    0.0            0  Quito  Pichincha
#
#            type  cluster  dcoilwtico
# date
# 2013-01-01    D       13       93.14
# 2013-01-01    D       13       93.14
# 2013-01-01    D       13       93.14
# 2013-01-01    D       13       93.14
# 2013-01-01    D       13       93.14

# %%
holidays_df = pd.read_csv('/content/holidays_events.csv')

holidays_df = holidays_df[holidays_df['transferred'] == False].copy()
holidays_df['holiday_type'] = holidays_df['type']
holidays_df.drop(['transferred', 'description', 'type'], axis=1, inplace=True)

national_holidays = holidays_df[holidays_df['locale'] == 'National'].copy()
national_holidays['national_holiday_type'] = national_holidays['holiday_type']
national_holidays.drop(['locale', 'locale_name', 'holiday_type'], axis=1, inplace=True)
national_holidays.drop_duplicates(subset='date', keep="first", inplace=True)
national_holidays['date'] = pd.to_datetime(national_holidays['date'])
train_df = pd.merge(train_df, national_holidays, how='left', on=['date'])
state_holidays = holidays_df[holidays_df['locale'] == 'Regional'].copy()
state_holidays['state'] = state_holidays['locale_name']
state_holidays['state_holiday_type'] = state_holidays['holiday_type']
state_holidays.drop(['locale', 'locale_name', 'holiday_type'], axis=1, inplace=True)
state_holidays['date'] = pd.to_datetime(state_holidays['date'])
train_df = pd.merge(train_df, state_holidays, how='left', on=['date', 'state'])

city_holidays = holidays_df[holidays_df['locale'] == 'Local'].copy()
city_holidays['city'] = city_holidays['locale_name']
city_holidays['city_holiday_type'] = city_holidays['holiday_type']
city_holidays.drop(['locale', 'locale_name', 'holiday_type'], axis=1, inplace=True)
city_holidays.drop([265], axis=0, inplace=True)
city_holidays['date'] = pd.to_datetime(city_holidays['date'])
train_df = pd.merge(train_df, city_holidays, how='left', on=['date', 'city'])

del city_holidays
del state_holidays
del national_holidays

train_df.head()
# Out:
#         date  id  store_nbr      family  sales  onpromotion   city      state  \
# 0 2013-01-01   0          1  AUTOMOTIVE    0.0            0  Quito  Pichincha
# 1 2013-01-01   1          1   BABY CARE    0.0            0  Quito  Pichincha
# 2 2013-01-01   2          1      BEAUTY    0.0            0  Quito  Pichincha
# 3 2013-01-01   3          1   BEVERAGES    0.0            0  Quito  Pichincha
# 4 2013-01-01   4          1       BOOKS    0.0            0  Quito  Pichincha
#
#   type  cluster  dcoilwtico national_holiday_type state_holiday_type  \
# 0    D       13       93.14               Holiday                NaN
# 1    D       13       93.14               Holiday                NaN
# 2    D       13       93.14               Holiday                NaN
# 3    D       13       93.14               Holiday                NaN
# 4    D       13       93.14               Holiday                NaN
#
#   city_holiday_type
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
train_df.fillna('', inplace=True)

# %%
ordinal_encoder = OrdinalEncoder(dtype=int)
train_df[['family']] = ordinal_encoder.fit_transform(train_df[['family']])
train_df[['national_holiday_type']] = ordinal_encoder.fit_transform(train_df[['national_holiday_type']])
train_df[['state_holiday_type']] = ordinal_encoder.fit_transform(train_df[['state_holiday_type']])
train_df[['city_holiday_type']] = ordinal_encoder.fit_transform(train_df[['city_holiday_type']])

# %%
del train_df['city']
del train_df['state']
del train_df['type']
train_df.head()
# Out:
#         date  id  store_nbr  family  sales  onpromotion  cluster  dcoilwtico  \
# 0 2013-01-01   0          1       0    0.0            0       13       93.14
# 1 2013-01-01   1          1       1    0.0            0       13       93.14
# 2 2013-01-01   2          1       2    0.0            0       13       93.14
# 3 2013-01-01   3          1       3    0.0            0       13       93.14
# 4 2013-01-01   4          1       4    0.0            0       13       93.14
#
#    national_holiday_type  state_holiday_type  city_holiday_type
# 0                      4                   0                  0
# 1                      4                   0                  0
# 2                      4                   0                  0
# 3                      4                   0                  0
# 4                      4                   0                  0

# %%
import seaborn as sns

# Compute the correlation matrix
corr_matrix = train_df.corr()

# Create a heatmap using seaborn
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt='.2f')
# Out:
# <ipython-input-26-c79fd6c2bc40>:4: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <Axes: >

# %%
grouped_df = train_df.groupby(['date']).agg({'sales': 'sum','dcoilwtico': 'mean', 
                                                 'onpromotion': 'sum',
                                                 'national_holiday_type': 'mean',
                                                 'city_holiday_type': 'mean',
                                                 'state_holiday_type': 'mean'})

grouped_df.head()
# Out:
#                     sales  dcoilwtico  onpromotion  national_holiday_type  \
# date
# 2013-01-01    2511.618999   93.140000            0                    4.0
# 2013-01-02  496092.417944   93.140000            0                    0.0
# 2013-01-03  361461.231124   92.970000            0                    0.0
# 2013-01-04  354459.677093   93.120000            0                    0.0
# 2013-01-05  477350.121229   93.146667            0                    6.0
#
#             city_holiday_type  state_holiday_type
# date
# 2013-01-01                0.0                 0.0
# 2013-01-02                0.0                 0.0
# 2013-01-03                0.0                 0.0
# 2013-01-04                0.0                 0.0
# 2013-01-05                0.0                 0.0

# %%
scaler  = MinMaxScaler()
scaled_grouped_df = scaler.fit_transform(grouped_df)
scaled_grouped_df.shape
# Out:
# (1684, 6)

# %%
features = scaled_grouped_df
target = scaled_grouped_df[:,0]

features.shape
# Out:
# (1684, 6)

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state= 4, shuffle= False)

# %%
win_length = 50
batch_size = 32
input_features = 6  

# create timeseries generators for train and test data
train_generator = TimeseriesGenerator(features, target, length=win_length,
                                      sampling_rate=1, batch_size=batch_size)
test_generator = TimeseriesGenerator(features, target, length=win_length,
                                     sampling_rate=1, batch_size=batch_size)

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv1D(filters=32, kernel_size=5, activation='relu', input_shape=(win_length, input_features)))
model.add(tf.keras.layers.MaxPooling1D(pool_size=2))
model.add(tf.keras.layers.Conv1D(filters=64, kernel_size=5, activation='relu'))
model.add(tf.keras.layers.MaxPooling1D(pool_size=2))
model.add(tf.keras.layers.Conv1D(filters=128, kernel_size=5, activation='relu'))
model.add(tf.keras.layers.MaxPooling1D(pool_size=2))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Dense(1))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 46, 32)            992
#
#  max_pooling1d (MaxPooling1D  (None, 23, 32)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 19, 64)            10304
#
#  max_pooling1d_1 (MaxPooling  (None, 9, 64)            0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 5, 128)            41088
#
#  max_pooling1d_2 (MaxPooling  (None, 2, 128)           0
#  1D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 68,897
# Trainable params: 68,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss= tf.losses.MeanSquaredError(),
             optimizer= tf.optimizers.Adam(),
             metrics =[tf.metrics.MeanAbsoluteError()])


history = model.fit(train_generator, epochs =100,
                              validation_data= test_generator,
                              shuffle = False)
# Out:
# Epoch 1/100
# 52/52 [==============================] - 13s 14ms/step - loss: 0.0243 - mean_absolute_error: 0.1222 - val_loss: 0.0541 - val_mean_absolute_error: 0.1862
# Epoch 2/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0300 - mean_absolute_error: 0.1375 - val_loss: 0.1899 - val_mean_absolute_error: 0.3354
# Epoch 3/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0515 - mean_absolute_error: 0.1740 - val_loss: 0.0576 - val_mean_absolute_error: 0.2019
# Epoch 4/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0290 - mean_absolute_error: 0.1330 - val_loss: 0.0727 - val_mean_absolute_error: 0.2156
# Epoch 5/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0330 - mean_absolute_error: 0.1419 - val_loss: 0.0174 - val_mean_absolute_error: 0.1097
# Epoch 6/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0195 - mean_absolute_error: 0.1097 - val_loss: 0.0323 - val_mean_absolute_error: 0.1573
# Epoch 7/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0195 - mean_absolute_error: 0.1106 - val_loss: 0.0193 - val_mean_absolute_error: 0.1177
# Epoch 8/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0171 - mean_absolute_error: 0.1034 - val_loss: 0.0179 - val_mean_absolute_error: 0.1114
# Epoch 9/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0174 - mean_absolute_error: 0.1025 - val_loss: 0.0140 - val_mean_absolute_error: 0.0966
# Epoch 10/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0189 - mean_absolute_error: 0.1052 - val_loss: 0.0131 - val_mean_absolute_error: 0.0932
# Epoch 11/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0150 - mean_absolute_error: 0.0957 - val_loss: 0.0115 - val_mean_absolute_error: 0.0860
# Epoch 12/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0138 - mean_absolute_error: 0.0920 - val_loss: 0.0126 - val_mean_absolute_error: 0.0932
# Epoch 13/100
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0134 - mean_absolute_error: 0.0904 - val_loss: 0.0133 - val_mean_absolute_error: 0.0963
# Epoch 14/100
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0126 - mean_absolute_error: 0.0882 - val_loss: 0.0099 - val_mean_absolute_error: 0.0804
# Epoch 15/100
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0115 - mean_absolute_error: 0.0829 - val_loss: 0.0173 - val_mean_absolute_error: 0.1119
# Epoch 16/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0116 - mean_absolute_error: 0.0841 - val_loss: 0.0098 - val_mean_absolute_error: 0.0819
# Epoch 17/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0103 - mean_absolute_error: 0.0789 - val_loss: 0.0157 - val_mean_absolute_error: 0.1053
# Epoch 18/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0109 - mean_absolute_error: 0.0810 - val_loss: 0.0079 - val_mean_absolute_error: 0.0724
# Epoch 19/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0088 - mean_absolute_error: 0.0732 - val_loss: 0.0153 - val_mean_absolute_error: 0.1048
# Epoch 20/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0094 - mean_absolute_error: 0.0753 - val_loss: 0.0085 - val_mean_absolute_error: 0.0753
# Epoch 21/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0107 - mean_absolute_error: 0.0822 - val_loss: 0.0095 - val_mean_absolute_error: 0.0814
# Epoch 22/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0115 - mean_absolute_error: 0.0843 - val_loss: 0.0150 - val_mean_absolute_error: 0.1077
# Epoch 23/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0141 - mean_absolute_error: 0.0941 - val_loss: 0.0072 - val_mean_absolute_error: 0.0689
# Epoch 24/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0102 - mean_absolute_error: 0.0788 - val_loss: 0.0068 - val_mean_absolute_error: 0.0650
# Epoch 25/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0091 - mean_absolute_error: 0.0743 - val_loss: 0.0089 - val_mean_absolute_error: 0.0678
# Epoch 26/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0100 - mean_absolute_error: 0.0758 - val_loss: 0.0115 - val_mean_absolute_error: 0.0842
# Epoch 27/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0120 - mean_absolute_error: 0.0846 - val_loss: 0.0172 - val_mean_absolute_error: 0.1069
# Epoch 28/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0116 - mean_absolute_error: 0.0827 - val_loss: 0.0075 - val_mean_absolute_error: 0.0711
# Epoch 29/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0080 - mean_absolute_error: 0.0705 - val_loss: 0.0075 - val_mean_absolute_error: 0.0731
# Epoch 30/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0076 - mean_absolute_error: 0.0684 - val_loss: 0.0073 - val_mean_absolute_error: 0.0720
# Epoch 31/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0075 - mean_absolute_error: 0.0679 - val_loss: 0.0061 - val_mean_absolute_error: 0.0583
# Epoch 32/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0080 - mean_absolute_error: 0.0677 - val_loss: 0.0051 - val_mean_absolute_error: 0.0564
# Epoch 33/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0078 - mean_absolute_error: 0.0694 - val_loss: 0.0055 - val_mean_absolute_error: 0.0556
# Epoch 34/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0069 - mean_absolute_error: 0.0646 - val_loss: 0.0055 - val_mean_absolute_error: 0.0571
# Epoch 35/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0071 - mean_absolute_error: 0.0651 - val_loss: 0.0059 - val_mean_absolute_error: 0.0615
# Epoch 36/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0075 - mean_absolute_error: 0.0670 - val_loss: 0.0092 - val_mean_absolute_error: 0.0770
# Epoch 37/100
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0078 - mean_absolute_error: 0.0687 - val_loss: 0.0175 - val_mean_absolute_error: 0.1059
# Epoch 38/100
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0093 - mean_absolute_error: 0.0727 - val_loss: 0.0059 - val_mean_absolute_error: 0.0627
# Epoch 39/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0068 - mean_absolute_error: 0.0656 - val_loss: 0.0063 - val_mean_absolute_error: 0.0664
# Epoch 40/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0060 - mean_absolute_error: 0.0594 - val_loss: 0.0054 - val_mean_absolute_error: 0.0615
# Epoch 41/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0057 - mean_absolute_error: 0.0593 - val_loss: 0.0040 - val_mean_absolute_error: 0.0466
# Epoch 42/100
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0059 - mean_absolute_error: 0.0593 - val_loss: 0.0073 - val_mean_absolute_error: 0.0740
# Epoch 43/100
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0061 - mean_absolute_error: 0.0610 - val_loss: 0.0039 - val_mean_absolute_error: 0.0470
# Epoch 44/100
# 52/52 [==============================] - 1s 17ms/step - loss: 0.0054 - mean_absolute_error: 0.0562 - val_loss: 0.0040 - val_mean_absolute_error: 0.0474
# Epoch 45/100
# 52/52 [==============================] - 1s 16ms/step - loss: 0.0047 - mean_absolute_error: 0.0524 - val_loss: 0.0039 - val_mean_absolute_error: 0.0476
# Epoch 46/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0050 - mean_absolute_error: 0.0532 - val_loss: 0.0039 - val_mean_absolute_error: 0.0500
# Epoch 47/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0054 - mean_absolute_error: 0.0565 - val_loss: 0.0065 - val_mean_absolute_error: 0.0594
# Epoch 48/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0055 - mean_absolute_error: 0.0550 - val_loss: 0.0046 - val_mean_absolute_error: 0.0539
# Epoch 49/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0053 - mean_absolute_error: 0.0562 - val_loss: 0.0044 - val_mean_absolute_error: 0.0536
# Epoch 50/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0051 - mean_absolute_error: 0.0546 - val_loss: 0.0137 - val_mean_absolute_error: 0.0961
# Epoch 51/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0066 - mean_absolute_error: 0.0615 - val_loss: 0.0048 - val_mean_absolute_error: 0.0570
# Epoch 52/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0053 - mean_absolute_error: 0.0558 - val_loss: 0.0035 - val_mean_absolute_error: 0.0473
# Epoch 53/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0048 - mean_absolute_error: 0.0543 - val_loss: 0.0040 - val_mean_absolute_error: 0.0479
# Epoch 54/100
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0051 - mean_absolute_error: 0.0544 - val_loss: 0.0044 - val_mean_absolute_error: 0.0514
# Epoch 55/100
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0062 - mean_absolute_error: 0.0597 - val_loss: 0.0122 - val_mean_absolute_error: 0.0939
# Epoch 56/100
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0079 - mean_absolute_error: 0.0699 - val_loss: 0.0050 - val_mean_absolute_error: 0.0542
# Epoch 57/100
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0066 - mean_absolute_error: 0.0634 - val_loss: 0.0057 - val_mean_absolute_error: 0.0616
# Epoch 58/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0065 - mean_absolute_error: 0.0635 - val_loss: 0.0032 - val_mean_absolute_error: 0.0429
# Epoch 59/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0057 - mean_absolute_error: 0.0600 - val_loss: 0.0061 - val_mean_absolute_error: 0.0583
# Epoch 60/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0058 - mean_absolute_error: 0.0597 - val_loss: 0.0040 - val_mean_absolute_error: 0.0492
# Epoch 61/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0062 - mean_absolute_error: 0.0620 - val_loss: 0.0059 - val_mean_absolute_error: 0.0580
# Epoch 62/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0049 - mean_absolute_error: 0.0538 - val_loss: 0.0070 - val_mean_absolute_error: 0.0647
# Epoch 63/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0050 - mean_absolute_error: 0.0540 - val_loss: 0.0066 - val_mean_absolute_error: 0.0645
# Epoch 64/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0061 - mean_absolute_error: 0.0603 - val_loss: 0.0122 - val_mean_absolute_error: 0.0892
# Epoch 65/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0070 - mean_absolute_error: 0.0641 - val_loss: 0.0048 - val_mean_absolute_error: 0.0560
# Epoch 66/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0049 - mean_absolute_error: 0.0537 - val_loss: 0.0032 - val_mean_absolute_error: 0.0442
# Epoch 67/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0045 - mean_absolute_error: 0.0520 - val_loss: 0.0028 - val_mean_absolute_error: 0.0410
# Epoch 68/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0044 - mean_absolute_error: 0.0510 - val_loss: 0.0046 - val_mean_absolute_error: 0.0517
# Epoch 69/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0059 - mean_absolute_error: 0.0595 - val_loss: 0.0039 - val_mean_absolute_error: 0.0469
# Epoch 70/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0064 - mean_absolute_error: 0.0614 - val_loss: 0.0058 - val_mean_absolute_error: 0.0556
# Epoch 71/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0046 - mean_absolute_error: 0.0525 - val_loss: 0.0073 - val_mean_absolute_error: 0.0633
# Epoch 72/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0049 - mean_absolute_error: 0.0542 - val_loss: 0.0096 - val_mean_absolute_error: 0.0755
# Epoch 73/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0046 - mean_absolute_error: 0.0517 - val_loss: 0.0072 - val_mean_absolute_error: 0.0684
# Epoch 74/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0055 - mean_absolute_error: 0.0571 - val_loss: 0.0174 - val_mean_absolute_error: 0.1038
# Epoch 75/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0081 - mean_absolute_error: 0.0689 - val_loss: 0.0161 - val_mean_absolute_error: 0.1010
# Epoch 76/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0079 - mean_absolute_error: 0.0680 - val_loss: 0.0064 - val_mean_absolute_error: 0.0662
# Epoch 77/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0054 - mean_absolute_error: 0.0585 - val_loss: 0.0043 - val_mean_absolute_error: 0.0521
# Epoch 78/100
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0050 - mean_absolute_error: 0.0550 - val_loss: 0.0047 - val_mean_absolute_error: 0.0533
# Epoch 79/100
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0049 - mean_absolute_error: 0.0546 - val_loss: 0.0078 - val_mean_absolute_error: 0.0692
# Epoch 80/100
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0043 - mean_absolute_error: 0.0503 - val_loss: 0.0066 - val_mean_absolute_error: 0.0642
# Epoch 81/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0035 - mean_absolute_error: 0.0450 - val_loss: 0.0068 - val_mean_absolute_error: 0.0662
# Epoch 82/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0036 - mean_absolute_error: 0.0459 - val_loss: 0.0052 - val_mean_absolute_error: 0.0594
# Epoch 83/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0039 - mean_absolute_error: 0.0483 - val_loss: 0.0084 - val_mean_absolute_error: 0.0744
# Epoch 84/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0038 - mean_absolute_error: 0.0465 - val_loss: 0.0049 - val_mean_absolute_error: 0.0590
# Epoch 85/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0039 - mean_absolute_error: 0.0475 - val_loss: 0.0051 - val_mean_absolute_error: 0.0585
# Epoch 86/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0039 - mean_absolute_error: 0.0477 - val_loss: 0.0032 - val_mean_absolute_error: 0.0453
# Epoch 87/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0035 - mean_absolute_error: 0.0448 - val_loss: 0.0057 - val_mean_absolute_error: 0.0624
# Epoch 88/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0037 - mean_absolute_error: 0.0462 - val_loss: 0.0029 - val_mean_absolute_error: 0.0422
# Epoch 89/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0037 - mean_absolute_error: 0.0459 - val_loss: 0.0045 - val_mean_absolute_error: 0.0560
# Epoch 90/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0035 - mean_absolute_error: 0.0455 - val_loss: 0.0030 - val_mean_absolute_error: 0.0418
# Epoch 91/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0032 - mean_absolute_error: 0.0436 - val_loss: 0.0050 - val_mean_absolute_error: 0.0604
# Epoch 92/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0044 - mean_absolute_error: 0.0512 - val_loss: 0.0070 - val_mean_absolute_error: 0.0712
# Epoch 93/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0038 - mean_absolute_error: 0.0472 - val_loss: 0.0149 - val_mean_absolute_error: 0.1045
# Epoch 94/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0044 - mean_absolute_error: 0.0509 - val_loss: 0.0091 - val_mean_absolute_error: 0.0815
# Epoch 95/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0038 - mean_absolute_error: 0.0460 - val_loss: 0.0143 - val_mean_absolute_error: 0.1018
# Epoch 96/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0046 - mean_absolute_error: 0.0524 - val_loss: 0.0046 - val_mean_absolute_error: 0.0551
# Epoch 97/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0031 - mean_absolute_error: 0.0427 - val_loss: 0.0059 - val_mean_absolute_error: 0.0634
# Epoch 98/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0033 - mean_absolute_error: 0.0433 - val_loss: 0.0029 - val_mean_absolute_error: 0.0411
# Epoch 99/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0030 - mean_absolute_error: 0.0419 - val_loss: 0.0052 - val_mean_absolute_error: 0.0565
# Epoch 100/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0032 - mean_absolute_error: 0.0419 - val_loss: 0.0080 - val_mean_absolute_error: 0.0772

# %%
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.legend()
plt.show()

# %%
mae = history.history['mean_absolute_error']
val_mae = history.history['val_mean_absolute_error']
mse = history.history['loss']
val_mse = history.history['val_loss']
epochs = range(1, len(mae) + 1)

plt.plot(epochs, mae, 'bo', label='Training MAE')
plt.plot(epochs, val_mae, 'b', label='Validation MAE')
plt.plot(epochs, mse, 'ro', label='Training MSE')
plt.plot(epochs, val_mse, 'r', label='Validation MSE')
plt.title('Training and validation metrics')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %%
test_metrics = model.evaluate(test_generator, verbose=0)
test_mse = test_metrics[0]
test_mae = test_metrics[1]
print(f"Test MSE: {test_mse:.4f}")
print(f"Test MAE: {test_mae:.4f}")
# Out:
# Test MSE: 0.0080
# Test MAE: 0.0772

# %%
predictions = model.predict(test_generator)
# Out:
# 52/52 [==============================] - 0s 4ms/step

# %%
df_pred = pd.concat([pd.DataFrame(predictions), pd.DataFrame(X_test[:,1:][win_length:])], axis = 1)
rev_trans = scaler.inverse_transform(df_pred)

# %%
df_final = grouped_df[predictions.shape[0]*-1:].copy()

# %%
df_final.count()
# Out:
# sales                    1634
# dcoilwtico               1634
# onpromotion              1634
# national_holiday_type    1634
# city_holiday_type        1634
# state_holiday_type       1634
# dtype: int64

# %%
df_final['predictions'] = rev_trans[:,0]

# %%
df_final[['sales','predictions']].plot()
# Out:
# <Axes: xlabel='date'>
